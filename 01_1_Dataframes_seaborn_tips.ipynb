# %% [markdown]
#  <img src="https://eant.tech/imagenes/logo.png" width=25% height=80%  >

# %% [markdown]
# ## <img src="http://icons.iconarchive.com/icons/cornmanthe3rd/plex/256/Other-python-icon.png" width="40"> Ejercicio Restaurant 🍝🍕🍟
#
# <center>
# <img src="https://i.ibb.co/ySBJX7L/25746.png" alt="25746" border="0" width="50%" height="30%">
# </center>

# %% [markdown]
# 🔹 1. Importar los paquetes que vamos a utilizar.
# > * pandas [`pd`]
# > * seaborn [`sns`]
# > * matplotlib.pyplot [`plt`]
# > * numpy [`np`]
# > * plotly [`px`]

# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# 🔹 2. Importar el dataframe tips que se encuentra en plotly

# %%
tips = px.data.tips()
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# 🔹 3. Visualizar las dos primeras filas del dataframe

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# 🔹 4. Vamos a generar nuestro primer grafico scatterplot donde:
#
# * x es total_bill
# * y es tip
#
# -------------
# Un **scatter plot**  es un tipo de grafico que utiliza las coordenadas cartesianas para mostrar los valores de dos variables para un conjunto de datos​.

# %%
sns.scatterplot(y = tips["tip"],
                x =tips["total_bill"])

# %%
plt.figure(figsize = (12,6))
sns.scatterplot(data = tips,
                x = "tip",
                y ="total_bill")
#plt.grid(True)
plt.ylabel('Propina')
plt.xlabel('Total Facturacion')
# Out:
# Text(0.5, 0, 'Total Facturacion')

# %%
plt.figure(figsize = (12,6))
plt.scatter(tips["total_bill"],tips["tip"])
plt.grid(True)
plt.ylabel('Propina')
plt.xlabel('Total de la mesa')
# Out:
# Text(0.5, 0, 'Total de la mesa')

# %% [markdown]
# 🔹 5. Modificar el tamaño del plot, por defecto tiene [ancho = 6.4, alto= 4.8], cambiar estos valores por [ancho = 20, alto= 5]

# %%
plt.figure(figsize = (20,5))
sns.scatterplot(data = tips,
                x = "tip",
                y ="total_bill")
#plt.grid(True)
plt.ylabel('Propina')
plt.xlabel('Total Facturacion')
# Out:
# Text(0.5, 0, 'Total Facturacion')

# %% [markdown]
# **🔹** 6. Modificar el color que tiene por defecto de azul y cambiarlo por el color rojo

# %%
plt.figure(figsize = (20,5))
sns.scatterplot(data = tips,
                y = "tip",
                x ="total_bill", 
                color = "purple")
#plt.grid(True)
plt.ylabel('Propina')
plt.xlabel('Total Facturacion')
# Out:
# Text(0.5, 0, 'Total Facturacion')

# %% [markdown]
# 🔹 7. Asignar un color en base a los valores de la variable denominada "day"

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = tips,
                y = "tip",
                x ="total_bill", 
                hue = "day")
#plt.grid(True)
plt.ylabel('Propina')
plt.xlabel('Total Facturacion')
# Out:
# Text(0.5, 0, 'Total Facturacion')

# %% [markdown]
# 🔹 8. Asignar un forma diferente a cada point en base a los valores de la variable denominada "smoker"

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = tips,
                y = "tip",
                x ="total_bill", 
                hue = "sex",
                style = "smoker",
                s = 100)
#plt.grid(True)
plt.ylabel('Propina')
plt.xlabel('Total Facturacion')
# Out:
# Text(0.5, 0, 'Total Facturacion')

# %% [markdown]
# 🔹 9. Cambiar la opacidad para que se pueda ver más transparente el color y asignar el valor 0.5

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = tips,
                y = "tip",
                x ="total_bill", 
                hue = "sex",
                style = "smoker",
                s = 100, 
                alpha = 0.7)
#plt.grid(True)
plt.ylabel('Propina')
plt.xlabel('Total Facturacion')
# Out:
# Text(0.5, 0, 'Total Facturacion')

# %% [markdown]
# 🔹 10. Ahora vamos a modificar los labels:
#
# >* 🏷️ Titulo: "Mi primer grafico en Python"
# >* 🏷️ Eje x: "Importe del Tickets"
# >* 🏷️ Eje y: "Propinas"

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = tips,
                y = "tip",
                x ="total_bill", 
                hue = "sex",
                style = "smoker",
                s = 100, 
                alpha = 0.7)
plt.title("Mi primer grafico en Python", fontsize = 20)
plt.ylabel('Propinas')
plt.xlabel('Importe Tickets')
# Out:
# Text(0.5, 0, 'Importe Tickets')

# %% [markdown]
# 🔹 11. Cambiar los colores asignados por defecto, por los colores verde y rojo Cambiemos el color asignado para la variable genero

# %%
sns.color_palette("Set3", n_colors=4)
# Out:
# [(0.5529411764705883, 0.8274509803921568, 0.7803921568627451),
#  (1.0, 1.0, 0.7019607843137254),
#  (0.7450980392156863, 0.7294117647058823, 0.8549019607843137),
#  (0.984313725490196, 0.5019607843137255, 0.4470588235294118)]

# %%
paleta = {"Female": "green", "Male": "red"}

# %%
sns.color_palette("Set3", n_colors=2)
# Out:
# [(0.5529411764705883, 0.8274509803921568, 0.7803921568627451),
#  (1.0, 1.0, 0.7019607843137254)]

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = tips.loc[tips["day"] == "Fri"  ,:],
                y = "tip",
                x ="total_bill", 
                hue = "sex",
                style = "smoker",
                #size="size", 
                #alpha = 0.7,
                s = 100,
                #sizes=(20, 200), 
                palette = sns.color_palette("viridis", n_colors=2))
plt.title("Mi primer grafico en Python", fontsize = 20)
plt.ylabel('Propinas')
plt.xlabel('Importe Tickets')
# Out:
# Text(0.5, 0, 'Importe Tickets')

# %% [markdown]
# 🔹 12. Agregamos otro tipo de grafico

# %%
plt.figure(figsize = (15,5))
sns.scatterplot(data = tips,
                y = "tip",
                x ="total_bill", 
                hue = "sex",
                style = "smoker",
                #size="size", 
                #alpha = 0.7,
                s = 100,
                #sizes=(20, 200), 
                palette = sns.color_palette("viridis", n_colors=2))

sns.lineplot(data = tips,
            y = "tip",
            x ="total_bill" , 
            hue = "sex",
            palette = sns.color_palette("viridis", n_colors=2))


plt.title("Mi primer grafico en Python", fontsize = 20)
plt.ylabel('Propinas')
plt.xlabel('Importe Tickets')
# Out:
# Text(0.5, 0, 'Importe Tickets')

# %%
plt.figure(figsize = (15,5))
sns.scatterplot(data = tips,
                x = "day",
                y ="total_bill", 
                hue = "day",
                style = "day",
                s = 100,
                palette = sns.color_palette("viridis", n_colors=4))

# %%
plt.figure(figsize = (15,5))
sns.stripplot(data = tips,
                x = "day",
                y ="total_bill", 
                hue = "sex",
                dodge = True,
                #palette = paleta
              )

# %%
plt.figure(figsize = (15,5))
sns.stripplot(data = tips,
                x = "day",
                y ="total_bill", 
                hue = "sex",
                dodge = True,
                #palette = paleta
              )

sns.boxplot(data = tips,
            saturation = 0.5,
                x = "day",
                y ="total_bill", 
                hue = "sex")

# %%
sns.lmplot(data = tips,
           x= "total_bill",
           y = "tip", 
           col ="day", 
           row = "smoker",
           ci = None,
           hue ="sex")

# %%
sns.jointplot(data = tips,
           x= "total_bill",
           y = "tip", 
           #kind = "reg", 
           hue = "sex")

# %% [markdown]
# 🔹 13. Generemos múltiples gráficas donde cada una de ellas pueda mostrar los datos relativos a un valor de la dimensión adicional.
# En nuestro caso generemos un scatter plot para cada uno de los 📅 dias de las semana.
# Agregemos los siguientes labels
# *   🏷️ Titulo: "Grafica en base a la variable day"
# *   🏷️ Eje x: "Importe del Tickets"
# *   🏷️ Eje y: "Propinas"

# %%
sns.relplot(data = tips,
            y = "tip",
            x ="total_bill", 
            height = 5,
            aspect = 2,
            row="day",
            hue = "sex",
            style = "smoker",
            s = 100,
            palette = sns.color_palette("viridis", n_colors=2),
            kind = "scatter")
plt.title("Mi primer grafico en Python", fontsize = 20)
plt.ylabel('Propinas')
plt.xlabel('Importe Tickets')
# Out:
# Text(0.5, 6.800000000000029, 'Importe Tickets')

# %% [markdown]
# 🔹 14. Generemos múltiples gráficas donde cada una de ellas pueda mostrar los datos relativos a un valor de la dimensión adicional.

# %%
sns.relplot(data = tips,
            y = "tip",
            x ="total_bill", 
            row="day",
            col = "smoker",
            hue = "sex",
            s = 100,
            palette = sns.color_palette("viridis", n_colors=2),
            kind = "scatter")

# %% [markdown]
# 🔹 15. Generemos un grafico con la distribución de la variable total_bill

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(20,5))
sns.histplot(data = tips, 
             stat = "probability",
             x = "total_bill", 
             bins = 20,
             #binwidth = 1,
             #hue = "sex",
             shrink = 0.95, kde = True             
             )

# %% [markdown]
# 🔹 16. Generemos un grafico con la distribución de la variable total_bill y tip

# %%
tips.tip.mean()
# Out:
# 2.9982786885245902

# %%
tips.total_bill.mean()
# Out:
# 19.785942622950824

# %%
plt.figure(figsize=(20,5))
sns.histplot(data = tips,
             x = "total_bill", 
             bins = 20,
             #binwidth = 3,
             #hue = "sex",
             shrink = 0.95,             
             )
sns.histplot(data = tips,
             x = "tip", 
             bins = 20,
             #binwidth = 3,
             #hue = "sex",
             shrink = 0.95,
             color = "red"             
             )
plt.vlines(tips.tip.mean(), 40 , 60, linestyles="dashed", colors="black")
plt.vlines(tips.total_bill.mean(), 40,60, linestyles="dashed", colors="black")
plt.hlines(40,0,60, linestyles= "dotted", colors= "black")
plt.xlim(0,55)
# Out:
# (0.0, 55.0)

# %% [markdown]
# -----------------------------
# ###📊 Barplot
# El barplot es una gráfica de barras,donde en el eje x se coloca una variable categórica y las frecuencias en el eje y.
# Para cada factor se genera una barra con alturas proporcionales a la frecuencias
#
# 🔹 17.  Generar un barplot donde en el eje x se encuentre la variable day

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips["day"].value_counts().index
# Out:
# Index(['Sat', 'Sun', 'Thur', 'Fri'], dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = tips,
              x = "day", 
              order = tips["day"].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = tips,
              y = "day",
              order = tips["day"].value_counts().index,
              palette = 'Purples_r')
plt.show()

# %% [markdown]
# 🔹 18.   Agregamos la variable "sex"

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = tips,
              y = "day",
              order = tips["day"].value_counts().index,
              palette = 'Set1',
              hue ="sex")
plt.show()

# %%
tips["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
cantidad = pd.DataFrame({"Dias": tips["day"].value_counts().index,
                        "Cantidad":tips["day"].value_counts().values })

# %%
cantidad
# Out:
#    Dias  Cantidad
# 0   Sat        87
# 1   Sun        76
# 2  Thur        62
# 3   Fri        19

# %%
#agregar etiquetas ejemplo
plt.figure(figsize=(10,5))
g = sns.barplot(data = cantidad,
                x= "Dias",
                y = "Cantidad")
for p in  g.patches:
  g.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=12,
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.ylim(0, 100) 
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = tips["day"].value_counts().index,
            y = tips["day"].value_counts().values)

# %%
sns.barplot(data = tips, 
            x = "day",
            y = "total_bill")

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = tips,
              x = "day",
              order = tips["day"].value_counts().index,
              palette = 'Set1',
              hue ="sex",
              #dodge= False
              )
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data = tips,
             x = "day",
             #order = tips["day"].value_counts().index,
             palette = 'Set1',
             multiple = "fill",# {“layer”, “dodge”, “stack”, “fill”}
             hue ="sex"
              )
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data = tips,
             hue = "day",
             #order = tips["day"].value_counts().index,
             palette = 'Set1',
             multiple = "fill",# {“layer”, “dodge”, “stack”, “fill”}
             x ="sex",
             stat ="probability"# ver mas opciones
              )
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data = tips,
             x = "day",
             #order = tips["day"].value_counts().index,
             palette = 'Set1',
             multiple = "stack",
             hue ="smoker"
              )
plt.show()

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# -----------------------------
# ###📊 Boxplot
# El boxplot es un gráfico para visualizar la distribución de una variable numérica  usando cuantiles.
#
# 🔹 18. Generemos nuestro boxplot donde en el x este la variable day y en el eje y total_bill

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = tips, 
            y = "day",
            x = "total_bill")

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = tips,
             y = "day",
             x = "total_bill"
             #hue ="smoker"
             )
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = tips,
             x = "day",
             y = "total_bill", 
            hue = "sex",
             #hue ="smoker"
             )

# %%
plt.figure(figsize=(10,5))
sns.stripplot(data = tips,
             x = "day",
             y = "total_bill", 
             hue = "sex",
             dodge = True
             #hue ="smoker"
             )

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = tips,
             x = "day",
             y = "total_bill", 
            hue = "sex",
             #hue ="smoker"
             )

sns.stripplot(data = tips,
             x = "day",
             y = "total_bill", 
             hue = "sex",
             dodge = True
             #hue ="smoker"
             )

plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = tips,
             x = "day",
             hue = "sex")

# %% [markdown]
# ----------------
# 🔍 Se pueden buscar paletas de colores en algunas de estas paginas:
#
#
# *   ✏️ **[Adobe Color](https://color.adobe.com/es/explore)**
# *   ✏️ **[Image Color Picke](https://imagecolorpicker.com/)**
# *   ✏️ **[Color Brewer 2](https://colorbrewer2.org/#type=sequential&scheme=BuGn&n=3)**
#
#
# Un color HEX se expresa como una combinación de seis dígitos de números y letras definidos por su combinación de 🔴 rojo, 📗 verde y 🔷 azul (RGB).
# Como por ejemplo:
# <br>
#
# <center>
# <img src="https://img.microsiervos.com/images2018/RGB_ColorHex.jpg" width="70%" height="60%">
# </center>

# %% [markdown]
# 🔹 19. Generemos nuestro boxplot donde en el x este la variable day y en el eje y total_bill, asignar los colores siguientes:
#
# *   #8FB6FF
# *   #76E8A4

# %%
paleta
# Out:
# {'Female': 'green', 'Male': 'red'}

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data = tips,
            x = "day",
            y = "total_bill", 
            hue = "smoker",
            palette = ["#8FB6FF","#76E8A4"]
             )

sns.stripplot(data = tips,
             x = "day",
             y = "total_bill", 
             hue = "sex",
             color = "black",
             alpha = 0.5,
             dodge = True,
             )

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data = tips,
            x = "day",
            y = "total_bill", 
            hue = "sex",
            split = True,
            palette = ["#8FB6FF","#76E8A4"]
             )
sns.stripplot(data = tips,
             x = "day",
             y = "total_bill", 
             hue = "sex",
             color = "black",
             alpha = 0.5,
             dodge = True,
             )

# sns.boxplot(data = tips,
#             x = "day",
#             y = "total_bill", 
#             hue = "smoker",
#             palette = ["#8FB6FF","#76E8A4"]
#              )

# %% [markdown]
# 🔹 20. Generar una variable denominada quintil_tip y quintil_total_bill que tenga los valores del 1 al 5 para definir en que quintil esta cada observación

# %%
m_labels = range(1,6)
# Out:
# [1, 2, 3, 4, 5]

# %%
tips["quintil_tip"]  = pd.qcut(tips["tip"],
        q = 5,
        labels = m_labels )

# %%
tips["quintil_total_bill"]  = pd.qcut(tips["total_bill"],
        q = 5,
        labels = m_labels )

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  ...    time size  quintil_tip quintil_total_bill
# 0       16.99  1.01  Female     No  ...  Dinner    2            1                  3
# 1       10.34  1.66    Male     No  ...  Dinner    3            1                  1
#
# [2 rows x 9 columns]

# %% [markdown]
# 🔹 21. Generar un heatmap en base a las variables: quintil_total_bill y day

# %%
pd.crosstab(tips["sex"], tips["day"], normalize= True, margins= True )
# Out:
# day          Fri       Sat       Sun      Thur       All
# sex
# Female  0.036885  0.114754  0.073770  0.131148  0.356557
# Male    0.040984  0.241803  0.237705  0.122951  0.643443
# All     0.077869  0.356557  0.311475  0.254098  1.000000

# %%
pd.crosstab(tips["sex"], tips["day"], 
            values = tips["tip"],
            aggfunc= "mean", 
            margins = True
            )
# Out:
# day          Fri       Sat       Sun      Thur       All
# sex
# Female  2.781111  2.801786  3.367222  2.575625  2.833448
# Male    2.693000  3.083898  3.220345  2.980333  3.089618
# All     2.734737  2.993103  3.255132  2.771452  2.998279

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'quintil_tip', 'quintil_total_bill'],
#       dtype='object')

# %%
pd.crosstab(tips["day"], tips['quintil_total_bill'])
# Out:
# quintil_total_bill   1   2   3   4   5
# day
# Fri                  7   4   2   3   3
# Sat                 15  18  15  20  19
# Sun                 10  13  16  19  18
# Thur                17  14  15   7   9

# %%
plt.figure(figsize=(15,8))
sns.heatmap(pd.crosstab(tips["day"], tips['quintil_total_bill']), annot= True, linewidths=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(pd.crosstab(tips['smoker'], tips["day"], values = tips["tip"], aggfunc= "mean" ), annot= True, linewidths=1, 
            #cmap = "Greens"
            )

# %% [markdown]
# 🔹 22. Utilicemos alguna de las siguientes paletas de colores:
# "YlGnBu","Blues","BuPu" y "Greens".

# %%
plt.figure(figsize=(15,8))
sns.heatmap(pd.crosstab(tips['sex'], tips["day"]), annot= True, linewidths=1, cmap = "Blues")

# %%
plt.figure(figsize=(15,8))
sns.heatmap(tips.corr(), annot= True, linewidths= 1)

# %% [markdown]
# 🔹 23. Generar un grafico pairplot con los datos de tips

# %%
plt.figure(figsize=(15,8))
sns.pairplot(tips, hue = "smoker", 
             #kind = "kde"
             )
